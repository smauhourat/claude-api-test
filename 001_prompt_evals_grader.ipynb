# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
# dataset = generate_dataset()
# with open("dataset.json", "w") as f:
#     json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Region Extraction Function\n\nHere's a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\nfrom urllib.parse import urlparse\n\ndef extract_region_from_s3_url(s3_url: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Supports formats:\n    - s3://bucket-name.region.amazonaws.com/key\n    - https://bucket-name.s3.region.amazonaws.com/key\n    - https://s3.region.amazonaws.com/bucket-name/key\n    \n    Args:\n        s3_url (str): The S3 URL to parse\n        \n    Returns:\n        str: The AWS region name\n        \n    Raises:\n        ValueError: If the region cannot be extracted from the URL\n    \"\"\"\n    \n    # Pattern 1: s3://bucket-name.region.amazonaws.com/key\n    match = re.search(r's3://[^.]+\\.([^.]+)\\.amazonaws\\.com', s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 2: https://bucket-name.s3.region.amazonaws.com/key\n    match = re.search(r'https://[^.]+\\.s3\\.([^.]+)\\.amazonaws\\.com', s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 3: https://s3.region.amazonaws.com/bucket-name/key\n    match = re.search(r'https://s3\\.([^.]+)\\.amazonaws\\.com', s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 4: https://bucket-name.s3.amazonaws.com (us-east-1, no region in URL)\n    if 's3.amazonaws.com' in s3_url and '.s3.amazonaws.com' in s3_url:\n        return 'us-east-1'\n    \n    raise ValueError(f\"Could not extract region from URL: {s3_url}\")\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_urls = [\n        \"s3://my-bucket.us-west-2.amazonaws.com/path/to/file\",\n        \"https://my-bucket.s3.eu-west-1.amazonaws.com/file.txt\",\n        \"https://s3.ap-southeast-1.amazonaws.com/my-bucket/file\",\n        \"https://my-bucket.s3.amazonaws.com/file.txt\",  # us-east-1\n        \"s3://data-bucket.ca-central-1.amazonaws.com/data\",\n    ]\n    \n    for url in test_urls:\n        try:\n            region = extract_region_from_s3_url(url)\n            print(f\"\u2713 {url}\")\n            print(f\"  Region: {region}\\n\")\n        except ValueError as e:\n            print(f\"\u2717 {url}\")\n            print(f\"  Error: {e}\\n\")\n```\n\n**Output:**\n```\n\u2713 s3://my-bucket.us-west-2.amazonaws.com/path/to/file\n  Region: us-west-2\n\n\u2713 https://my-bucket.s3.eu-west-1.amazonaws.com/file.txt\n  Region: eu-west-1\n\n\u2713 https://s3.ap-southeast-1.amazonaws.com/my-bucket/file\n  Region: ap-southeast-1\n\n\u2713 https://my-bucket.s3.amazonaws.com/file.txt\n  Region: us-east-1\n\n\u2713 s3://data-bucket.ca-central-1.amazonaws.com/data\n  Region: ca-central-1\n```\n\n## Alternative Simpler Version\n\nIf you only need to support the specific format mentioned in the task:\n\n```python\nimport re\n\ndef extract_region_from_s3_url(s3_url: str) -> str:\n    \"\"\"\n    Extracts the AWS region from S3 URL format: s3",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com/key'. Return the region name."
#     },
#     "score": 7,
#     "reasoning": "The solution exceeds the task requirements by supporting multiple S3 URL formats, which is valuable. However, there are regex quality issues that could cause false positives or unexpected behavior with malformed URLs. The incomplete alternate implementation and the Pattern 4 logic flaw are notable defects. Despite these issues, the core functionality works for well-formed URLs and the code is well-structured and documented."
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket':\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\",\n        \"s3:ListBucketVersions\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown:\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version |\n| **Statement 1** | Allows reading objects within the bucket |\n| **Statement 2** | Allows listing bucket contents and checking bucket location |\n| **Resource ARN (/*)** | Applies to all objects in the bucket |\n| **Resource ARN (no /*)** | Applies to the bucket itself |\n\nThis policy provides the minimum permissions needed for read-only S3 access without allowing any write, delete, or bucket modification operations.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses the core requirement with valid IAM policy syntax and proper resource targeting. The two-statement structure properly distinguishes between bucket-level and object-level permissions. However, the policy includes some permissions that may be beyond strict 'read-only access' needs (GetObjectTagging, ListBucketVersions) without justification. The policy is functional and secure but could be more precisely scoped. The documentation is clear but could better explain trade-offs between functionality and least-privilege."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix required for EC2 instance IDs |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9, a-f) |\n| `{17}` | Quantifier requiring exactly 17 hex characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid Matches \u2713\n```\ni-0a1b2c3d4e5f6g7h8\ni-1234567890abcdef0\ni-ffffffffffffffff0\n```\n\n### Invalid (Non-Matches) \u2717\n```\ni-0a1b2c3d4e5f6g7h      (only 16 chars)\ni-0a1b2c3d4e5f6g7h8i    (18 chars)\n0a1b2c3d4e5f6g7h8       (missing 'i-' prefix)\ni-0a1b2c3d4e5f6g7hZ     (contains uppercase Z, invalid hex)\n```\n\n## Language-Specific Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nre.match(pattern, 'i-1234567890abcdef0')\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\npattern.test('i-1234567890abcdef0');\n```\n\n**Note:** If your implementation needs to match uppercase hex characters as well, use: `^i-[0-9a-fA-F]{17}$`",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs, which follow the pattern 'i-' followed by 17 hexadecimal characters."
#     },
#     "score": 6,
#     "reasoning": "The regex pattern itself is technically correct and solves the stated problem. However, the solution contains a significant credibility issue: the example data contradicts the regex pattern. The character 'g' is used in examples labeled as valid matches, but 'g' is not hexadecimal (only 0-9, a-f are valid). This is a critical error that undermines confidence in the solution, even though the actual regex pattern works correctly. The documentation quality is otherwise good with clear formatting and practical language examples."
#   }
# ]
