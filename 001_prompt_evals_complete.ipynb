# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-s3-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"TARGET_BUCKET_NAME\": \"my-target-bucket\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"Code\": {\n    \"S3Bucket\": \"my-lambda-code-bucket\",\n    \"S3Key\": \"lambda-function.zip\"\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-source-bucket\",\n        \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for the target bucket name and log level",
#       "format": "json",
#       "solution_criteria": "Must include valid JSON structure with Lambda runtime configuration, S3 event source mapping, and environment variables section with at least bucket name and log level keys"
#     },
#     "score": 8.0,
#     "reasoning": "The solution successfully meets the core requirement of creating a valid JSON configuration with Lambda runtime settings, environment variables (bucket name and log level), and S3 integration. However, the Events section uses non-standard AWS Lambda API syntax - the 'Events' key at the Lambda level is specific to SAM templates, not the standard CreateFunction API. For actual AWS Lambda deployment, event source mapping should be configured separately or the template syntax should match the intended deployment method. The configuration is functional for SAM templates but would fail with standard AWS Lambda API calls."
#   },
#   {
#     "output": "\nimport re\n\ndef extract_cloudwatch_log(log_message):\n    \"\"\"\n    Extract timestamp, log level, and message content from AWS CloudWatch log message.\n    \n    Expected format: YYYY-MM-DD HH:MM:SS [LOG_LEVEL] message content\n    Example: 2024-01-15 10:30:45 [INFO] Application started successfully\n    \"\"\"\n    pattern = r'(\\d{4}-\\d{2}-\\d{2} \\d{2}:\\d{2}:\\d{2})\\s+\\[(\\w+)\\]\\s+(.+)'\n    \n    match = re.match(pattern, log_message.strip())\n    \n    if match:\n        return {\n            'timestamp': match.group(1),\n            'log_level': match.group(2),\n            'message': match.group(3)\n        }\n    return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_logs = [\n        \"2024-01-15 10:30:45 [INFO] Application started successfully\",\n        \"2024-01-15 10:31:12 [ERROR] Database connection failed\",\n        \"2024-01-15 10:32:00 [DEBUG] Processing request from 192.168.1.1\",\n        \"2024-01-15 10:33:22 [WARNING] Memory usage at 85%\"\n    ]\n    \n    for log in test_logs:\n        result = extract_cloudwatch_log(log)\n        print(result)\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch log message and extracts the timestamp, log level, and message content using regex pattern matching",
#       "format": "python",
#       "solution_criteria": "Function should accept a log string and return a dictionary with 'timestamp', 'log_level', and 'message' keys; must handle standard CloudWatch format (e.g., '[ERROR] 2024-01-15T10:30:45Z Message text')"
#     },
#     "score": 6.5,
#     "reasoning": "While the solution is well-written with good code practices, it fundamentally fails the core requirement. The regex pattern and expected format do not match the CloudWatch standard specified in the criteria. Real AWS CloudWatch logs use ISO 8601 timestamps with milliseconds/timezone and typically have log level at the beginning. The test cases work but validate against the wrong format, not actual CloudWatch logs. This is a significant functional failure despite good code structure."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[\\w+=,.@\\-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that validates AWS IAM role ARN format (arn:aws:iam::account-id:role/role-name)",
#       "format": "regex",
#       "solution_criteria": "Regex must match valid IAM role ARNs, accept 12-digit account IDs, allow alphanumeric characters, hyphens and underscores in role names, and reject invalid formats"
#     },
#     "score": 8.5,
#     "reasoning": "The regex demonstrates solid understanding of ARN structure and correctly handles the fixed components and account ID validation. However, the role name validation is loose\u2014the current pattern [\\w+=,.@\\-]+ technically works but allows unnecessary characters and could theoretically permit edge cases not valid in AWS. The pattern would benefit from more precise constraints on role name length and character restrictions to strictly match AWS IAM naming rules."
#   }
# ]
