# %%
# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API Client
import anthropic

client = anthropic.Anthropic()
model="claude-sonnet-4-0"

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistan_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages, system=None):
    params = {
        "model":model,
        "max_tokens":1024,
        "messages":messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(
        **params
    )
    return message.content[0].text

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
add_user_message(messages, "How do I solve 5x+3=2 for x")
answer = chat(messages)
answer
# Out:
# 'To solve 5x + 3 = 2 for x, I need to isolate x by using inverse operations.\n\n**Step 1:** Subtract 3 from both sides to eliminate the +3\n5x + 3 - 3 = 2 - 3\n5x = -1\n\n**Step 2:** Divide both sides by 5 to eliminate the coefficient of x\n5x ÷ 5 = -1 ÷ 5\nx = -1/5\n\n**Answer:** x = -1/5 (or -0.2 as a decimal)\n\n**Check:** Let me verify by substituting back into the original equation:\n5(-1/5) + 3 = -1 + 3 = 2 ✓'
